# %% [markdown]
# FINE TUNING ON  COMBINED DATASET (FaceForensics++, SythASpoof and ReplayAttck )

# %%
# !pip install -q tensorflow tensorflow-addons ffmpeg-python opencv-python-headless numpy
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 611.8/611.8 kB 11.1 MB/s eta 0:00:00a 0:00:01
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ydata-profiling 4.16.1 requires typeguard<5,>=3, but you have typeguard 2.13.3 which is incompatible.
# inflect 7.5.0 requires typeguard>=4.0.1, but you have typeguard 2.13.3 which is incompatible.

# %%
#Delete all the existing contents of Output directory
import shutil
import os

working_dir = '/kaggle/working'

# Loop through all items and remove them
for item in os.listdir(working_dir):
    item_path = os.path.join(working_dir, item)
    try:
        if os.path.isfile(item_path) or os.path.islink(item_path):
            os.remove(item_path)
        elif os.path.isdir(item_path):
            shutil.rmtree(item_path)
    except Exception as e:
        print(f'Failed to delete {item_path}. Reason: {e}')

print("All contents of /kaggle/working have been deleted.")
# Out:
# All contents of /kaggle/working have been deleted.

# %%
#  Consolidate the 3 datasets (with sampling) into /kaggle/working/dataset3/{real,fake}

import os
import glob
import shutil
import random

# 1. Paths to your three input roots
SYNTH_ROOT  = '/kaggle/input/synthaspoof/SynthASpoof/SynthASpoof'
ROSE_ROOT   = '/kaggle/input/rose-frames/kaggle/working/frames'
REPLAY_ROOT = '/kaggle/input/frames-replay-attack'

# 2. Destination
DST_ROOT = '/kaggle/working/dataset3'
REAL_DIR = os.path.join(DST_ROOT, 'real')
FAKE_DIR = os.path.join(DST_ROOT, 'fake')
os.makedirs(REAL_DIR, exist_ok=True)
os.makedirs(FAKE_DIR, exist_ok=True)

# 3. Utility to copy a list of files with prefix
def copy_list(fps, dst_dir, prefix=""):
    for fp in fps:
        fname = os.path.basename(fp)
        dst = os.path.join(dst_dir, prefix + fname)
        shutil.copy2(fp, dst)

# Fix seed for reproducibility
random.seed(42)

# 4. SYNTHASPOOF
# 4a) BonaFide → real (sample 50%)
bf_paths = glob.glob(os.path.join(SYNTH_ROOT, 'BonaFide', '*.*'))
sample_bf = random.sample(bf_paths, k=len(bf_paths)//2)
copy_list(sample_bf, REAL_DIR, prefix='synth_BonaFide_')

# 4b) PAs/* → fake (sample 50% from each subfolder)
pa_root = os.path.join(SYNTH_ROOT, 'PAs')
for sub in os.listdir(pa_root):
    subdir = os.path.join(pa_root, sub)
    if os.path.isdir(subdir):
        pa_paths = glob.glob(os.path.join(subdir, '*.*'))
        sample_pa = random.sample(pa_paths, k=len(pa_paths)//2)
        copy_list(sample_pa, FAKE_DIR, prefix=f'synth_PA_{sub}_')

# 5. ROSE‑frames
# 5a) real → real (sample 50%)
rose_real = glob.glob(os.path.join(ROSE_ROOT, 'real', '*.*'))
sample_rr = random.sample(rose_real, k=len(rose_real)//2)
copy_list(sample_rr, REAL_DIR, prefix='rose_real_')

# 5b) fake → fake (sample 50%)
rose_fake = glob.glob(os.path.join(ROSE_ROOT, 'fake', '*.*'))
sample_rf = random.sample(rose_fake, k=len(rose_fake)//2)
copy_list(sample_rf, FAKE_DIR, prefix='rose_fake_')

# 6. FRAMES‑REPLAY‑ATTACK (take ALL)
# 6a) real → real
replay_real = glob.glob(os.path.join(REPLAY_ROOT, 'real', '*.*'))
copy_list(replay_real, REAL_DIR, prefix='replay_real_')

# 6b) fake → fake
replay_fake = glob.glob(os.path.join(REPLAY_ROOT, 'fake', '*.*'))
copy_list(replay_fake, FAKE_DIR, prefix='replay_fake_')

# 7. Summary
print(f"TOTAL REAL count: {len(os.listdir(REAL_DIR))}")
print(f"TOTAL FAKE count: {len(os.listdir(FAKE_DIR))}")
# Out:
# TOTAL REAL count: 21105
# TOTAL FAKE count: 53669

# %%
#Split the combined dataset 
import os
import glob
import random
import shutil

# 1. Configuration
SRC_ROOT   = '/kaggle/working/dataset3'
DST_ROOT   = '/kaggle/working/dataset3_split'
CLASSES    = ['real','fake']
RATIOS     = (0.7, 0.15, 0.15)  # train, val, test
SEED       = 42

random.seed(SEED)

# 2. Create destination directories
for split in ['train','val','test']:
    for cls in CLASSES:
        os.makedirs(os.path.join(DST_ROOT, split, cls), exist_ok=True)

# 3. Split each class
for cls in CLASSES:
    src_dir = os.path.join(SRC_ROOT, cls)
    files   = sorted(glob.glob(os.path.join(src_dir, '*.*')))
    random.shuffle(files)
    
    n = len(files)
    n_train = int(n * RATIOS[0])
    n_val   = int(n * (RATIOS[0] + RATIOS[1]))
    
    splits = {
        'train': files[:n_train],
        'val':   files[n_train:n_val],
        'test':  files[n_val:]
    }
    
    # 4. Copy into each split folder
    for split, fps in splits.items():
        dst_dir = os.path.join(DST_ROOT, split, cls)
        for fp in fps:
            fname = os.path.basename(fp)
            shutil.copy2(fp, os.path.join(dst_dir, fname))

# 5. Report counts
for split in ['train','val','test']:
    for cls in CLASSES:
        cnt = len(os.listdir(os.path.join(DST_ROOT, split, cls)))
        print(f"{split}/{cls}: {cnt} images")
# Out:
# train/real: 14773 images
# train/fake: 37568 images
# val/real: 3166 images
# val/fake: 8050 images
# test/real: 3166 images
# test/fake: 8051 images

# %%
# #Downlaod the test dataset for future testing 
# !zip -r /kaggle/working/test.zip /kaggle/working/dataset3_split/test
# from IPython.display import FileLink
# FileLink('/kaggle/working/test.zip')

# %%
# Cell 2: Model Training & Periodic Saving with Focal Loss
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, applications, callbacks
import numpy as np
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt
import os

# 1. Configuration
IMG_SIZE    = (224, 224)
BATCH_SIZE  = 128
EPOCH_HEAD  = 5
EPOCH_FINE  = 30    # total fine‑tune epochs
CLASS_NAMES = ['real', 'fake']
DATA_DIR    = '/kaggle/working/dataset3_split'

# 2. tf.data pipelines
def build_ds(split, augment=False):
    ds = keras.utils.image_dataset_from_directory(
        os.path.join(DATA_DIR, split),
        labels='inferred', label_mode='categorical',
        class_names=CLASS_NAMES,
        image_size=IMG_SIZE, batch_size=BATCH_SIZE,
        shuffle=(split == 'train'), seed=42
    )
    ds = ds.map(lambda x, y: (layers.Rescaling(1./255)(x), y),
                num_parallel_calls=tf.data.AUTOTUNE)
    if augment and split == 'train':
        aug = keras.Sequential([
            layers.RandomFlip('horizontal'),
            layers.RandomRotation(0.05),
            layers.RandomContrast(0.2),
        ])
        ds = ds.map(lambda x, y: (aug(x), y), num_parallel_calls=tf.data.AUTOTUNE)
    return ds.prefetch(tf.data.AUTOTUNE)

train_ds = build_ds('train', augment=True)
val_ds   = build_ds('val')
test_ds  = build_ds('test')
# Out:
# Found 52341 files belonging to 2 classes.
# Found 11216 files belonging to 2 classes.
# Found 11217 files belonging to 2 classes.

# %%
from tensorflow import keras
from tensorflow.keras import layers, callbacks, applications

# 3. Model definition
base = applications.EfficientNetB0(
    input_shape=(*IMG_SIZE, 3), include_top=False,
    weights='imagenet', pooling='avg'
)
base.trainable = False

inp = keras.Input(shape=(*IMG_SIZE, 3))
x   = base(inp, training=False)
x   = layers.Dropout(0.3)(x)
out = layers.Dense(len(CLASS_NAMES), activation='softmax')(x)
model = keras.Model(inputs=inp, outputs=out)

# 4. Custom callback to save every N epochs in .keras format
class SaveEveryNEpoch(callbacks.Callback):
    def __init__(self, n, prefix="EB0_all_e"):
        super().__init__()
        self.n = n
        self.prefix = prefix

    def on_epoch_end(self, epoch, logs=None):
        if (epoch + 1) % self.n == 0:
            ep = epoch + 1
            keras_path = f"{self.prefix}{ep}.keras"
            # save full model in the native Keras format
            self.model.save(keras_path)
            print(f"\n→ Saved checkpoint: {keras_path}\n")

# 5. Callbacks
cbs = [
    callbacks.ReduceLROnPlateau(monitor='val_auc', factor=0.5, patience=2),
    callbacks.EarlyStopping(monitor='val_auc', patience=4, restore_best_weights=True),
    SaveEveryNEpoch(n=10, prefix="EB0_all_e"),
    # Save the best full model (not just weights) in .keras format
    callbacks.ModelCheckpoint(
        "video_model_latest.keras",
        save_weights_only=False,
        monitor='val_auc',
        mode='max',
        save_best_only=True,
        verbose=1
    )
]

# 6. Stage 1: train head only
focal_loss = keras.losses.CategoricalFocalCrossentropy(
    alpha=0.25, gamma=2.0, from_logits=False
)

model.compile(
    optimizer=keras.optimizers.Adam(1e-3),
    loss=focal_loss,
    metrics=['accuracy', keras.metrics.AUC(name='auc')]
)
model.fit(train_ds, validation_data=val_ds,
          epochs=EPOCH_HEAD, callbacks=cbs)

# 7. Stage 2: fine-tune backbone
base.trainable = True
model.compile(
    optimizer=keras.optimizers.Adam(1e-4),
    loss=focal_loss,
    metrics=['accuracy', keras.metrics.AUC(name='auc')]
)
model.fit(train_ds, validation_data=val_ds,
          epochs=EPOCH_FINE, callbacks=cbs)

# 8. Final evaluation
loss, acc, auc = model.evaluate(test_ds, verbose=2)
print(f"Test → loss: {loss:.4f}, acc: {acc:.4f}, auc: {auc:.4f}")

# 9. Confusion matrix
import numpy as np
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt

y_true = np.concatenate([y.numpy() for _, y in test_ds], axis=0)
preds = model.predict(test_ds)
y_pred = np.argmax(preds, axis=1)
y_true = np.argmax(y_true, axis=1)

cm   = confusion_matrix(y_true, y_pred)
disp = ConfusionMatrixDisplay(cm, display_labels=CLASS_NAMES)
disp.plot(cmap=plt.cm.Blues)
plt.title("Combined Test Confusion Matrix")
plt.show()
# Out:
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb0_notop.h5
# 16705208/16705208 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Epoch 1/5
# 409/409 ━━━━━━━━━━━━━━━━━━━━ 0s 561ms/step - accuracy: 0.6836 - auc: 0.7069 - loss: 0.0405
# Epoch 1: val_auc improved from -inf to 0.71777, saving model to video_model_latest.keras
# 409/409 ━━━━━━━━━━━━━━━━━━━━ 287s 634ms/step - accuracy: 0.6837 - auc: 0.7069 - loss: 0.0405 - val_accuracy: 0.7177 - val_auc: 0.7178 - val_loss: 0.0379 - learning_rate: 0.0010
# Epoch 2/5
# 409/409 ━━━━━━━━━━━━━━━━━━━━ 0s 539ms/step - accuracy: 0.7128 - auc: 0.7193 - loss: 0.0387
# Epoch 2: val_auc improved from 0.71777 to 0.71821, saving model to video_model_latest.keras
# 409/409 ━━━━━━━━━━━━━━━━━━━━ 235s 572ms/step - accuracy: 0.7128 - auc: 0.7193 - loss: 0.0387 - val_accuracy: 0.7177 - val_auc: 0.7182 - val_loss: 0.0385 - learning_rate: 0.0010
# Epoch 3/5
# 409/409 ━━━━━━━━━━━━━━━━━━━━ 0s 523ms/step - accuracy: 0.7159 - auc: 0.7180 - loss: 0.0385
# Epoch 3: val_auc did not improve from 0.71821
# 409/409 ━━━━━━━━━━━━━━━━━━━━ 228s 553ms/step - accuracy: 0.7159 - auc: 0.7180 - loss: 0.0385 - val_accuracy: 0.7177 - val_auc: 0.7175 - val_loss: 0.0380 - learning_rate: 0.0010
# Epoch 4/5
# 409/409 ━━━━━━━━━━━━━━━━━━━━ 0s 521ms/step - accuracy: 0.7154 - auc: 0.7187 - loss: 0.0385
# Epoch 4: val_auc improved from 0.71821 to 0.72774, saving model to video_model_latest.keras
# 409/409 ━━━━━━━━━━━━━━━━━━━━ 228s 553ms/step - accuracy: 0.7154 - auc: 0.7187 - loss: 0.0385 - val_accuracy: 0.7177 - val_auc: 0.7277 - val_loss: 0.0382 - learning_rate: 0.0010
# Epoch 5/5
# 409/409 ━━━━━━━━━━━━━━━━━━━━ 0s 518ms/step - accuracy: 0.7154 - auc: 0.7161 - loss: 0.0385
# Epoch 5: val_auc improved from 0.72774 to 0.76287, saving model to video_model_latest.keras
# 409/409 ━━━━━━━━━━━━━━━━━━━━ 226s 550ms/step - accuracy: 0.7154 - auc: 0.7161 - loss: 0.0385 - val_accuracy: 0.7177 - val_auc: 0.7629 - val_loss: 0.0380 - learning_rate: 0.0010
# Epoch 1/30
# E0000 00:00:1748320361.640414     109 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1748320361.827405     109 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1748320362.749136     109 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1748320362.901291     109 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1748320363.488749     109 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1748320363.641482     109 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 408/409 ━━━━━━━━━━━━━━━━━━━━ 0s 555ms/step - accuracy: 0.9161 - auc: 0.9662 - loss: 0.0125
# E0000 00:00:1748320635.052290     108 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1748320635.236698     108 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1748320635.997625     108 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1748320636.149918     108 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1748320636.740259     108 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1748320636.893363     108 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 409/409 ━━━━━━━━━━━━━━━━━━━━ 0s 669ms/step - accuracy: 0.9162 - auc: 0.9663 - loss: 0.0125
# Epoch 1: val_auc did not improve from 0.76287
# 409/409 ━━━━━━━━━━━━━━━━━━━━ 406s 727ms/step - accuracy: 0.9163 - auc: 0.9664 - loss: 0.0125 - val_accuracy: 0.6924 - val_auc: 0.7280 - val_loss: 0.0393 - learning_rate: 1.0000e-04
# Epoch 2/30
# 409/409 ━━━━━━━━━━━━━━━━━━━━ 0s 555ms/step - accuracy: 0.9931 - auc: 0.9997 - loss: 0.0013
# Epoch 2: val_auc did not improve from 0.76287
# 409/409 ━━━━━━━━━━━━━━━━━━━━ 242s 586ms/step - accuracy: 0.9931 - auc: 0.9997 - loss: 0.0013 - val_accuracy: 0.6471 - val_auc: 0.7059 - val_loss: 0.0554 - learning_rate: 1.0000e-04
# Epoch 3/30
# 409/409 ━━━━━━━━━━━━━━━━━━━━ 0s 993ms/step - accuracy: 0.9973 - auc: 0.9999 - loss: 5.9661e-04
# Epoch 3: val_auc did not improve from 0.76287
# 409/409 ━━━━━━━━━━━━━━━━━━━━ 420s 1s/step - accuracy: 0.9973 - auc: 0.9999 - loss: 5.9655e-04 - val_accuracy: 0.7082 - val_auc: 0.7626 - val_loss: 0.0524 - learning_rate: 1.0000e-04
# Epoch 4/30
# 409/409 ━━━━━━━━━━━━━━━━━━━━ 0s 555ms/step - accuracy: 0.9982 - auc: 1.0000 - loss: 3.6384e-04
# Epoch 4: val_auc improved from 0.76287 to 0.87623, saving model to video_model_latest.keras
# 409/409 ━━━━━━━━━━━━━━━━━━━━ 242s 588ms/step - accuracy: 0.9982 - auc: 1.0000 - loss: 3.6378e-04 - val_accuracy: 0.7257 - val_auc: 0.8762 - val_loss: 0.0995 - learning_rate: 1.0000e-04
# Epoch 5/30
# 409/409 ━━━━━━━━━━━━━━━━━━━━ 0s 557ms/step - accuracy: 0.9991 - auc: 1.0000 - loss: 2.1479e-04
# Epoch 5: val_auc improved from 0.87623 to 0.89043, saving model to video_model_latest.keras
# 409/409 ━━━━━━━━━━━━━━━━━━━━ 263s 591ms/step - accuracy: 0.9991 - auc: 1.0000 - loss: 2.1484e-04 - val_accuracy: 0.7683 - val_auc: 0.8904 - val_loss: 0.0549 - learning_rate: 5.0000e-05
# Epoch 6/30
# 409/409 ━━━━━━━━━━━━━━━━━━━━ 0s 989ms/step - accuracy: 0.9990 - auc: 1.0000 - loss: 1.9608e-04
# Epoch 6: val_auc did not improve from 0.89043
# 409/409 ━━━━━━━━━━━━━━━━━━━━ 437s 1s/step - accuracy: 0.9990 - auc: 1.0000 - loss: 1.9599e-04 - val_accuracy: 0.7207 - val_auc: 0.8166 - val_loss: 0.0995 - learning_rate: 5.0000e-05
# Epoch 7/30
# 409/409 ━━━━━━━━━━━━━━━━━━━━ 0s 612ms/step - accuracy: 0.9992 - auc: 1.0000 - loss: 1.6252e-04
# Epoch 7: val_auc improved from 0.89043 to 0.92916, saving model to video_model_latest.keras
# 409/409 ━━━━━━━━━━━━━━━━━━━━ 266s 646ms/step - accuracy: 0.9992 - auc: 1.0000 - loss: 1.6244e-04 - val_accuracy: 0.8310 - val_auc: 0.9292 - val_loss: 0.0526 - learning_rate: 2.5000e-05
# Epoch 8/30
# 409/409 ━━━━━━━━━━━━━━━━━━━━ 0s 988ms/step - accuracy: 0.9996 - auc: 1.0000 - loss: 1.0301e-04
# Epoch 8: val_auc improved from 0.92916 to 0.98160, saving model to video_model_latest.keras
# 409/409 ━━━━━━━━━━━━━━━━━━━━ 420s 1s/step - accuracy: 0.9996 - auc: 1.0000 - loss: 1.0301e-04 - val_accuracy: 0.9309 - val_auc: 0.9816 - val_loss: 0.0164 - learning_rate: 2.5000e-05
# Epoch 9/30
# 409/409 ━━━━━━━━━━━━━━━━━━━━ 0s 555ms/step - accuracy: 0.9996 - auc: 1.0000 - loss: 9.5859e-05
# Epoch 9: val_auc did not improve from 0.98160
# 409/409 ━━━━━━━━━━━━━━━━━━━━ 241s 586ms/step - accuracy: 0.9996 - auc: 1.0000 - loss: 9.5847e-05 - val_accuracy: 0.7216 - val_auc: 0.8040 - val_loss: 0.1372 - learning_rate: 1.2500e-05
# Epoch 10/30
# 409/409 ━━━━━━━━━━━━━━━━━━━━ 0s 554ms/step - accuracy: 0.9998 - auc: 1.0000 - loss: 5.6179e-05
# → Saved checkpoint: EB0_all_e10.keras
#
#
# Epoch 10: val_auc did not improve from 0.98160
# 409/409 ━━━━━━━━━━━━━━━━━━━━ 243s 589ms/step - accuracy: 0.9998 - auc: 1.0000 - loss: 5.6195e-05 - val_accuracy: 0.8837 - val_auc: 0.9505 - val_loss: 0.0292 - learning_rate: 1.2500e-05
# Epoch 11/30
# 360/409 ━━━━━━━━━━━━━━━━━━━━ 34s 710ms/step - accuracy: 0.9996 - auc: 1.0000 - loss: 8.5451e-05
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_35/2556254397.py in <cell line: 0>()
#      66     metrics=['accuracy', keras.metrics.AUC(name='auc')]
#      67 )
# ---> 68 model.fit(train_ds, validation_data=val_ds,
#      69           epochs=EPOCH_FINE, callbacks=cbs)
#      70
#
# /usr/local/lib/python3.11/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#     115         filtered_tb = None
#     116         try:
# --> 117             return fn(*args, **kwargs)
#     118         except Exception as e:
#     119             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.11/dist-packages/keras/src/backend/tensorflow/trainer.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq)
#     369                 for step, iterator in epoch_iterator:
#     370                     callbacks.on_train_batch_begin(step)
# --> 371                     logs = self.train_function(iterator)
#     372                     callbacks.on_train_batch_end(step, logs)
#     373                     if self.stop_training:
#
# /usr/local/lib/python3.11/dist-packages/keras/src/backend/tensorflow/trainer.py in function(iterator)
#     217                 iterator, (tf.data.Iterator, tf.distribute.DistributedIterator)
#     218             ):
# --> 219                 opt_outputs = multi_step_on_iterator(iterator)
#     220                 if not opt_outputs.has_value():
#     221                     raise StopIteration
#
# /usr/local/lib/python3.11/dist-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.11/dist-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py in __call__(self, *args, **kwds)
#     831
#     832       with OptionalXlaContext(self._jit_compile):
# --> 833         result = self._call(*args, **kwds)
#     834
#     835       new_tracing_count = self.experimental_get_tracing_count()
#
# /usr/local/lib/python3.11/dist-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py in _call(self, *args, **kwds)
#     876       # In this case we have not created variables on the first call. So we can
#     877       # run the first trace but we should fail if variables are created.
# --> 878       results = tracing_compilation.call_function(
#     879           args, kwds, self._variable_creation_config
#     880       )
#
# /usr/local/lib/python3.11/dist-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py in call_function(args, kwargs, tracing_options)
#     137   bound_args = function.function_type.bind(*args, **kwargs)
#     138   flat_inputs = function.function_type.unpack_inputs(bound_args)
# --> 139   return function._call_flat(  # pylint: disable=protected-access
#     140       flat_inputs, captured_inputs=function.captured_inputs
#     141   )
#
# /usr/local/lib/python3.11/dist-packages/tensorflow/python/eager/polymorphic_function/concrete_function.py in _call_flat(self, tensor_inputs, captured_inputs)
#    1320         and executing_eagerly):
#    1321       # No tape is watching; skip to running the function.
# -> 1322       return self._inference_function.call_preflattened(args)
#    1323     forward_backward = self._select_forward_and_backward_functions(
#    1324         args,
#
# /usr/local/lib/python3.11/dist-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py in call_preflattened(self, args)
#     214   def call_preflattened(self, args: Sequence[core.Tensor]) -> Any:
#     215     """Calls with flattened tensor inputs and returns the structured output."""
# --> 216     flat_outputs = self.call_flat(*args)
#     217     return self.function_type.pack_output(flat_outputs)
#     218
#
# /usr/local/lib/python3.11/dist-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py in call_flat(self, *args)
#     249         with record.stop_recording():
#     250           if self._bound_context.executing_eagerly():
# --> 251             outputs = self._bound_context.call_function(
#     252                 self.name,
#     253                 list(args),
#
# /usr/local/lib/python3.11/dist-packages/tensorflow/python/eager/context.py in call_function(self, name, tensor_inputs, num_outputs)
#    1681     cancellation_context = cancellation.context()
#    1682     if cancellation_context is None:
# -> 1683       outputs = execute.execute(
#    1684           name.decode("utf-8"),
#    1685           num_outputs=num_outputs,
#
# /usr/local/lib/python3.11/dist-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51   try:
#      52     ctx.ensure_initialized()
# ---> 53     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                         inputs, attrs, num_outputs)
#      55   except core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %%
model.save('/kaggle/working/EB0_all_v2.keras')
model.save('/kaggle/working/EB0_all_v2.h5')

# %%
#Download the combined dataset
# !zip -r /kaggle/working/dataset3_split/test.zip /kaggle/working/dataset3_split/test
# Out:
#   adding: kaggle/working/dataset3_split/test/ (stored 0%)
#   adding: kaggle/working/dataset3_split/test/fake/ (stored 0%)
#   adding: kaggle/working/dataset3_split/test/fake/synth_PA_iPad_ReplayAttack_img109625.png (deflated 1%)
#   adding: kaggle/working/dataset3_split/test/fake/synth_PA_Samsung_ReplayAttack_img094479.png (deflated 1%)
#   adding: kaggle/working/dataset3_split/test/fake/rose_fake_Ps_NT_HW_wg_E_23_106_frame_0000.jpg (deflated 1%)
#   adding: kaggle/working/dataset3_split/test/fake/rose_fake_Pq_NT_5s_wg_E_23_76_frame_0021.jpg (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/fake/rose_fake_Mf_NT_HS_wg_E_4_74_frame_0001.jpg (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/fake/rose_fake_Pq_NT_HS_wg_E_2_108_frame_0020.jpg (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/fake/rose_fake_Vl_NT_HS_g_E_11_144_frame_0008.jpg (deflated 2%)
#   adding: kaggle/working/dataset3_split/test/fake/synth_PA_PrintAttack_img063528.png (deflated 2%)
#   adding: kaggle/working/dataset3_split/test/fake/synth_PA_iPad_ReplayAttack_img092087.png (deflated 1%)
#   adding: kaggle/working/dataset3_split/test/fake/synth_PA_Samsung_ReplayAttack_img521028.png (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/fake/rose_fake_Vm_NT_ZTE_wg_E_12_179_frame_0001.jpg (deflated 2%)
#   adding: kaggle/working/dataset3_split/test/fake/synth_PA_PrintAttack_img063725.png (deflated 4%)
#   adding: kaggle/working/dataset3_split/test/fake/rose_fake_Pq_NT_HS_wg_E_13_109_frame_0004.jpg (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/fake/synth_PA_iPad_ReplayAttack_img043002.png (deflated 1%)
#   adding: kaggle/working/dataset3_split/test/fake/synth_PA_iPad_ReplayAttack_img440305.png (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/fake/synth_PA_Samsung_ReplayAttack_img231345.png (deflated 1%)
#   adding: kaggle/working/dataset3_split/test/fake/synth_PA_iPad_ReplayAttack_img399563.png (deflated 1%)
#   adding: kaggle/working/dataset3_split/test/fake/synth_PA_Samsung_ReplayAttack_img151286.png (deflated 1%)
#   adding: kaggle/working/dataset3_split/test/fake/synth_PA_Samsung_ReplayAttack_img173191.png (deflated 1%)
#   adding: kaggle/working/dataset3_split/test/fake/rose_fake_Vm_NT_ZTE_g_E_18_178_frame_0009.jpg (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/fake/synth_PA_Webcam_ReplayAttack_img211149.png (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/fake/synth_PA_iPad_ReplayAttack_img399128.png (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/fake/rose_fake_Vl_NT_HS_wg_E_7_123_frame_0003.jpg (deflated 1%)
#   adding: kaggle/working/dataset3_split/test/fake/synth_PA_Webcam_ReplayAttack_img187596.png (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/fake/rose_fake_Ps_NT_5s_g_E_17_122_frame_0007.jpg (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/fake/rose_fake_Vl_NT_HW_g_E_11_149_frame_0009.jpg (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/fake/synth_PA_Samsung_ReplayAttack_img243946.png (deflated 1%)
#   adding: kaggle/working/dataset3_split/test/fake/rose_fake_Vm_NT_HS_g_E_6_165_frame_0008.jpg (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/fake/rose_fake_Ps_NT_HS_wg_E_16_128_frame_0015.jpg (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/fake/synth_PA_iPad_ReplayAttack_img447112.png (deflated 1%)
#   adding: kaggle/working/dataset3_split/test/fake/synth_PA_PrintAttack_img020876.png (deflated 2%)
#   adding: kaggle/working/dataset3_split/test/fake/rose_fake_Pq_NT_IP_wg_E_11_114_frame_0013.jpg (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/fake/synth_PA_iPad_ReplayAttack_img286402.png (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/fake/synth_PA_iPad_ReplayAttack_img246019.png (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/fake/rose_fake_Ps_NT_HW_wg_E_12_132_frame_0009.jpg (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/fake/rose_fake_Pq_NT_5s_g_E_11_101_frame_0011.jpg (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/fake/synth_PA_Samsung_ReplayAttack_img372602.png (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/fake/synth_PA_Samsung_ReplayAttack_img281713.png (deflated 1%)
#   adding: kaggle/working/dataset3_split/test/fake/rose_fake_Ps_NT_ZTE_g_E_14_138_frame_0005.jpg (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/fake/synth_PA_PrintAttack_img011021.png (deflated 2%)
#   adding: kaggle/working/dataset3_split/test/fake/rose_fake_Vl_NT_5s_wg_E_21_144_frame_0016.jpg (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/fake/synth_PA_iPad_ReplayAttack_img107354.png (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/fake/synth_PA_Samsung_ReplayAttack_img057427.png (deflated 1%)
#   adding: kaggle/working/dataset3_split/test/fake/synth_PA_iPad_ReplayAttack_img503659.png (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/fake/synth_PA_iPad_ReplayAttack_img278617.png (deflated 1%)
#   adding: kaggle/working/dataset3_split/test/fake/synth_PA_iPad_ReplayAttack_img521661.png (deflated 1%)
#   adding: kaggle/working/dataset3_split/test/fake/synth_PA_Webcam_ReplayAttack_img474982.png (deflated 1%)
#   adding: kaggle/working/dataset3_split/test/fake/synth_PA_iPad_ReplayAttack_img008317.png (deflated 1%)
#   adding: kaggle/working/dataset3_split/test/fake/rose_fake_Ps_NT_HS_g_E_16_126_frame_0006.jpg (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/fake/synth_PA_Samsung_ReplayAttack_img454327.png (deflated 1%)
#   adding: kaggle/working/dataset3_split/test/fake/rose_fake_Mc_NT_ZTE_g_E_6_60_frame_0001.jpg (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/fake/synth_PA_Webcam_ReplayAttack_img275184.png (deflated 1%)
#   adding: kaggle/working/dataset3_split/test/fake/rose_fake_Vl_NT_5s_g_E_13_143_frame_0019.jpg (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/fake/rose_fake_Mc_T_HS_g_E_7_38_frame_0022.jpg (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/fake/rose_fake_Vl_NT_5s_wg_E_17_143_frame_0016.jpg (deflated 2%)
#   adding: kaggle/working/dataset3_split/test/fake/rose_fake_Mf_NT_5s_wg_E_23_47_frame_0015.jpg (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/fake/rose_fake_Mc_NT_ZTE_g_E_23_34_frame_0007.jpg (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/fake/rose_fake_Mc_NT_IP_g_E_16_57_frame_0012.jpg (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/fake/synth_PA_Webcam_ReplayAttack_img526433.png (deflated 1%)
#   adding: kaggle/working/dataset3_split/test/fake/rose_fake_Vm_NT_HW_g_E_17_170_frame_0011.jpg (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/fake/synth_PA_iPad_ReplayAttack_img388336.png (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/fake/synth_PA_iPad_ReplayAttack_img183962.png (deflated 1%)
#   adding: kaggle/working/dataset3_split/test/fake/rose_fake_Vl_NT_HW_wg_E_7_125_frame_0007.jpg (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/fake/synth_PA_Webcam_ReplayAttack_img014277.png (deflated 1%)
#   adding: kaggle/working/dataset3_split/test/fake/synth_PA_Samsung_ReplayAttack_img183944.png (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/fake/synth_PA_iPad_ReplayAttack_img051321.png (deflated 1%)
#   adding: kaggle/working/dataset3_split/test/fake/rose_fake_Mf_NT_HW_wg_E_4_76_frame_0006.jpg (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/fake/rose_fake_Ps_NT_IP_g_E_17_133_frame_0011.jpg (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/fake/synth_PA_Samsung_ReplayAttack_img224713.png (deflated 1%)
#   adding: kaggle/working/dataset3_split/test/fake/synth_PA_Samsung_ReplayAttack_img456706.png (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/fake/synth_PA_iPad_ReplayAttack_img492195.png (deflated 1%)
#   adding: kaggle/working/dataset3_split/test/fake/synth_PA_Webcam_ReplayAttack_img278820.png (deflated 1%)
#   adding: kaggle/working/dataset3_split/test/fake/synth_PA_Samsung_ReplayAttack_img076688.png (deflated 1%)
#   adding: kaggle/working/dataset3_split/test/fake/rose_fake_Pq_NT_IP_wg_E_3_116_frame_0005.jpg (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/fake/rose_fake_Mc_NT_IP_g_E_11_58_frame_0003.jpg (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/fake/synth_PA_iPad_ReplayAttack_img276050.png (deflated 1%)
#   adding: kaggle/working/dataset3_split/test/fake/rose_fake_Vm_NT_IP_g_E_13_175_frame_0018.jpg (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/fake/synth_PA_Samsung_ReplayAttack_img128396.png (deflated 1%)
#   adding: kaggle/working/dataset3_split/test/fake/synth_PA_iPad_ReplayAttack_img373510.png (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/fake/synth_PA_iPad_ReplayAttack_img011070.png (deflated 1%)
#   adding: kaggle/working/dataset3_split/test/fake/rose_fake_Vm_NT_5s_g_E_12_162_frame_0017.jpg (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/fake/synth_PA_iPad_ReplayAttack_img120158.png (deflated 1%)
#   adding: kaggle/working/dataset3_split/test/fake/synth_PA_Samsung_ReplayAttack_img299297.png (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/fake/rose_fake_Pq_NT_HS_g_E_4_106_frame_0002.jpg (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/fake/synth_PA_Samsung_ReplayAttack_img159603.png (deflated 1%)
#   adding: kaggle/working/dataset3_split/test/fake/synth_PA_Samsung_ReplayAttack_img479344.png (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/fake/synth_PA_iPad_ReplayAttack_img468691.png (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/fake/synth_PA_Samsung_ReplayAttack_img480315.png (deflated 1%)
#   adding: kaggle/working/dataset3_split/test/fake/rose_fake_Vm_NT_IP_wg_E_7_148_frame_0009.jpg (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/fake/rose_fake_Mu_T_5s_g_E_21_90_frame_0023.jpg (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/fake/synth_PA_Samsung_ReplayAttack_img250828.png (deflated 1%)
#   adding: kaggle/working/dataset3_split/test/fake/synth_PA_iPad_ReplayAttack_img542322.png (deflated 2%)
#   adding: kaggle/working/dataset3_split/test/fake/synth_PA_iPad_ReplayAttack_img033760.png (deflated 2%)
#   adding: kaggle/working/dataset3_split/test/fake/synth_PA_PrintAttack_img027069.png (deflated 2%)
#   adding: kaggle/working/dataset3_split/test/fake/synth_PA_iPad_ReplayAttack_img495307.png (deflated 1%)
#   adding: kaggle/working/dataset3_split/test/fake/rose_fake_Mc_T_5s_g_E_2_62_frame_0007.jpg (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/fake/rose_fake_Mc_NT_IP_g_E_15_33_frame_0008.jpg (deflated 1%)
#   adding: kaggle/working/dataset3_split/test/fake/rose_fake_Mu_T_IP_g_E_16_97_frame_0004.jpg (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/fake/rose_fake_Pq_NT_IP_g_E_3_113_frame_0003.jpg (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/fake/rose_fake_Ps_NT_HW_wg_E_7_107_frame_0005.jpg (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/fake/rose_fake_Mc_NT_5s_g_E_12_51_frame_0003.jpg (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/fake/rose_fake_Pq_NT_IP_wg_E_18_115_frame_0012.jpg (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/fake/synth_PA_iPad_ReplayAttack_img447220.png (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/fake/rose_fake_Vl_NT_5s_wg_E_10_116_frame_0009.jpg (deflated 1%)
#   adding: kaggle/working/dataset3_split/test/fake/synth_PA_iPad_ReplayAttack_img536999.png (deflated 1%)
#   adding: kaggle/working/dataset3_split/test/fake/rose_fake_Ps_NT_HS_wg_E_12_127_frame_0020.jpg (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/fake/synth_PA_Samsung_ReplayAttack_img413846.png (deflated 1%)
#   adding: kaggle/working/dataset3_split/test/fake/synth_PA_iPad_ReplayAttack_img118045.png (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/fake/synth_PA_Samsung_ReplayAttack_img245630.png (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/fake/rose_fake_Vl_NT_HW_g_E_16_150_frame_0011.jpg (deflated 1%)
#   adding: kaggle/working/dataset3_split/test/fake/rose_fake_Vl_NT_ZTE_wg_E_23_132_frame_0021.jpg (deflated 1%)
#   adding: kaggle/working/dataset3_split/test/fake/rose_fake_Pq_NT_HS_g_E_18_106_frame_0003.jpg (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/fake/synth_PA_Samsung_ReplayAttack_img373405.png (deflated 1%)
#   adding: kaggle/working/dataset3_split/test/fake/rose_fake_Vl_NT_IP_g_E_12_154_frame_0013.jpg (deflated 1%)
#   adding: kaggle/working/dataset3_split/test/fake/rose_fake_Pq_NT_IP_wg_E_6_115_frame_0015.jpg (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/fake/synth_PA_Samsung_ReplayAttack_img247386.png (deflated 1%)
#   adding: kaggle/working/dataset3_split/test/fake/synth_PA_Samsung_ReplayAttack_img344502.png (deflated 1%)
#   adding: kaggle/working/dataset3_split/test/fake/synth_PA_Samsung_ReplayAttack_img013598.png (deflated 1%)
#   adding: kaggle/working/dataset3_split/test/fake/rose_fake_Mu_NT_IP_g_E_21_87_frame_0017.jpg (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/fake/rose_fake_Mu_T_ZTE_g_E_9_99_frame_0000.jpg (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/fake/rose_fake_Mc_T_HS_g_E_21_64_frame_0019.jpg (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/fake/synth_PA_iPad_ReplayAttack_img431916.png (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/fake/rose_fake_Mf_NT_IP_g_E_12_76_frame_0014.jpg (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/fake/synth_PA_iPad_ReplayAttack_img348492.png (deflated 1%)
#   adding: kaggle/working/dataset3_split/test/fake/rose_fake_Vm_NT_ZTE_g_E_11_176_frame_0017.jpg (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/fake/synth_PA_Samsung_ReplayAttack_img062349.png (deflated 1%)
#   adding: kaggle/working/dataset3_split/test/fake/synth_PA_Samsung_ReplayAttack_img504510.png (deflated 1%)
#   adding: kaggle/working/dataset3_split/test/fake/synth_PA_iPad_ReplayAttack_img101622.png (deflated 1%)
#   adding: kaggle/working/dataset3_split/test/fake/synth_PA_Samsung_ReplayAttack_img291627.png (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/fake/synth_PA_Samsung_ReplayAttack_img388575.png (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/fake/synth_PA_Samsung_ReplayAttack_img068169.png (deflated 1%)
#   adding: kaggle/working/dataset3_split/test/fake/synth_PA_Samsung_ReplayAttack_img407070.png (deflated 1%)
#   adding: kaggle/working/dataset3_split/test/fake/synth_PA_Samsung_ReplayAttack_img101391.png (deflated 1%)
#   adding: kaggle/working/dataset3_split/test/fake/synth_PA_Samsung_ReplayAttack_img531491.png (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/fake/synth_PA_Samsung_ReplayAttack_img136812.png (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/fake/rose_fake_Mf_NT_HW_wg_E_16_76_frame_0013.jpg (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/fake/rose_fake_Pq_NT_IP_wg_E_7_89_frame_0003.jpg (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/fake/rose_fake_Ps_NT_ZTE_g_E_3_137_frame_0010.jpg (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/fake/synth_PA_iPad_ReplayAttack_img285735.png (deflated 1%)
#   adding: kaggle/working/dataset3_split/test/fake/synth_PA_iPad_ReplayAttack_img055720.png (deflated 1%)
#   adding: kaggle/working/dataset3_split/test/fake/synth_PA_Samsung_ReplayAttack_img342728.png (deflated 1%)
#   adding: kaggle/working/dataset3_split/test/fake/synth_PA_iPad_ReplayAttack_img083024.png (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/fake/synth_PA_Samsung_ReplayAttack_img024380.png (deflated 2%)
#   adding: kaggle/working/dataset3_split/test/fake/rose_fake_Pq_NT_HS_g_E_3_105_frame_0018.jpg (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/fake/rose_fake_Mu_T_HS_g_E_10_68_frame_0009.jpg (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/fake/rose_fake_Mc_NT_HS_g_E_15_28_frame_0021.jpg (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/fake/rose_fake_Mu_T_HW_g_E_9_96_frame_0003.jpg (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/fake/synth_PA_iPad_ReplayAttack_img417426.png (deflated 1%)
#   adding: kaggle/working/dataset3_split/test/fake/synth_PA_Samsung_ReplayAttack_img131414.png (deflated 1%)
#   adding: kaggle/working/dataset3_split/test/fake/synth_PA_iPad_ReplayAttack_img139633.png (deflated 1%)
#   adding: kaggle/working/dataset3_split/test/fake/synth_PA_iPad_ReplayAttack_img326298.png (deflated 1%)
#   adding: kaggle/working/dataset3_split/test/fake/rose_fake_Mu_T_IP_g_E_16_97_frame_0002.jpg (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/fake/synth_PA_iPad_ReplayAttack_img397216.png (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/fake/synth_PA_Samsung_ReplayAttack_img187448.png (deflated 1%)
#   adding: kaggle/working/dataset3_split/test/fake/rose_fake_Mc_T_5s_g_E_12_60_frame_0009.jpg (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/fake/rose_fake_Ps_NT_HS_g_E_14_126_frame_0007.jpg (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/fake/synth_PA_Webcam_ReplayAttack_img212911.png (deflated 1%)
#   adding: kaggle/working/dataset3_split/test/fake/synth_PA_iPad_ReplayAttack_img457726.png (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/fake/synth_PA_PrintAttack_img076670.png (deflated 2%)
#   adding: kaggle/working/dataset3_split/test/fake/synth_PA_Webcam_ReplayAttack_img496297.png (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/fake/synth_PA_Samsung_ReplayAttack_img490080.png (deflated 1%)
#   adding: kaggle/working/dataset3_split/test/fake/synth_PA_Samsung_ReplayAttack_img032788.png (deflated 2%)
#   adding: kaggle/working/dataset3_split/test/fake/synth_PA_iPad_ReplayAttack_img147277.png (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/fake/rose_fake_Mu_NT_HW_g_E_7_60_frame_0010.jpg (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/fake/rose_fake_Pq_NT_5s_g_E_12_102_frame_0003.jpg (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/fake/synth_PA_iPad_ReplayAttack_img314763.png (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/fake/rose_fake_Mc_NT_IP_g_E_18_57_frame_0004.jpg (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/fake/rose_fake_Pq_NT_5s_g_E_14_102_frame_0013.jpg (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/fake/rose_fake_Mc_NT_5s_g_E_12_52_frame_0011.jpg (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/fake/rose_fake_Mf_NT_IP_wg_E_15_53_frame_0006.jpg (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/fake/rose_fake_Mu_T_HW_g_E_3_96_frame_0005.jpg (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/fake/synth_PA_iPad_ReplayAttack_img217250.png (deflated 1%)
#   adding: kaggle/working/dataset3_split/test/fake/rose_fake_Mu_NT_IP_g_E_23_63_frame_0004.jpg (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/fake/rose_fake_Ps_NT_IP_wg_E_23_110_frame_0015.jpg (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/fake/synth_PA_Samsung_ReplayAttack_img169924.png (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/fake/synth_PA_Samsung_ReplayAttack_img277562.png (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/fake/rose_fake_Vm_NT_HW_wg_E_11_171_frame_0010.jpg (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/fake/rose_fake_Mc_T_5s_g_E_18_62_frame_0018.jpg (deflated 1%)
#   adding: kaggle/working/dataset3_split/test/fake/synth_PA_Samsung_ReplayAttack_img544176.png (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/fake/synth_PA_iPad_ReplayAttack_img449366.png (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/fake/synth_PA_Samsung_ReplayAttack_img149113.png (deflated 1%)
#   adding: kaggle/working/dataset3_split/test/fake/synth_PA_PrintAttack_img052437.png (deflated 3%)
#   adding: kaggle/working/dataset3_split/test/fake/rose_fake_Mc_T_IP_g_E_3_68_frame_0007.jpg (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/fake/synth_PA_iPad_ReplayAttack_img161668.png (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/fake/rose_fake_Vm_NT_HS_wg_E_15_139_frame_0015.jpg (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/fake/synth_PA_Samsung_ReplayAttack_img243151.png (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/fake/rose_fake_Mu_NT_5s_g_E_18_82_frame_0016.jpg (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/fake/rose_fake_Pq_NT_HS_wg_E_20_107_frame_0018.jpg (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/fake/synth_PA_Samsung_ReplayAttack_img532193.png (deflated 1%)
#   adding: kaggle/working/dataset3_split/test/fake/rose_fake_Vl_NT_ZTE_g_E_2_157_frame_0009.jpg (deflated 1%)
#   adding: kaggle/working/dataset3_split/test/fake/rose_fake_Mu_NT_5s_g_E_2_82_frame_0019.jpg (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/fake/synth_PA_Samsung_ReplayAttack_img247856.png (deflated 1%)
#   adding: kaggle/working/dataset3_split/test/fake/synth_PA_iPad_ReplayAttack_img063273.png (deflated 1%)
#   adding: kaggle/working/dataset3_split/test/fake/synth_PA_Samsung_ReplayAttack_img497988.png (deflated 1%)
#   adding: kaggle/working/dataset3_split/test/fake/synth_PA_iPad_ReplayAttack_img159021.png (deflated 1%)
#   adding: kaggle/working/dataset3_split/test/fake/synth_PA_iPad_ReplayAttack_img376745.png (deflated 2%)
#   adding: kaggle/working/dataset3_split/test/fake/synth_PA_iPad_ReplayAttack_img182305.png (deflated 2%)
#   adding: kaggle/working/dataset3_split/test/fake/synth_PA_Webcam_ReplayAttack_img072330.png (deflated 1%)
#   adding: kaggle/working/dataset3_split/test/fake/synth_PA_iPad_ReplayAttack_img095246.png (deflated 1%)
#   adding: kaggle/working/dataset3_split/test/fake/synth_PA_iPad_ReplayAttack_img051498.png (deflated 1%)
#   adding: kaggle/working/dataset3_split/test/fake/rose_fake_Vl_NT_HW_wg_E_7_124_frame_0006.jpg (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/fake/rose_fake_Vl_NT_ZTE_g_E_6_158_frame_0004.jpg (deflated 1%)
#   adding: kaggle/working/dataset3_split/test/fake/rose_fake_Vm_NT_HS_wg_E_23_142_frame_0002.jpg (deflated 1%)
#   adding: kaggle/working/dataset3_split/test/fake/synth_PA_Samsung_ReplayAttack_img517170.png (deflated 1%)
#   adding: kaggle/working/dataset3_split/test/fake/synth_PA_iPad_ReplayAttack_img160311.png (deflated 1%)
#   adding: kaggle/working/dataset3_split/test/fake/synth_PA_iPad_ReplayAttack_img269759.png (deflated 1%)
#   adding: kaggle/working/dataset3_split/test/fake/synth_PA_Webcam_ReplayAttack_img115541.png (deflated 1%)
#   adding: kaggle/working/dataset3_split/test/fake/rose_fake_Mc_NT_5s_g_E_10_27_frame_0007.jpg (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/fake/synth_PA_iPad_ReplayAttack_img206816.png (deflated 2%)
#   adding: kaggle/working/dataset3_split/test/fake/rose_fake_Mu_NT_5s_g_E_17_82_frame_0000.jpg (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/fake/synth_PA_Samsung_ReplayAttack_img395018.png (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/fake/rose_fake_Mf_NT_ZTE_wg_E_15_55_frame_0001.jpg (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/fake/rose_fake_Vm_NT_IP_wg_E_12_175_frame_0025.jpg (deflated 1%)
#   adding: kaggle/working/dataset3_split/test/fake/synth_PA_Samsung_ReplayAttack_img232233.png (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/fake/rose_fake_Ps_NT_5s_wg_E_20_122_frame_0018.jpg (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/fake/rose_fake_Vl_NT_5s_wg_E_11_142_frame_0016.jpg (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/fake/rose_fake_Mu_T_IP_g_E_16_98_frame_0020.jpg (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/fake/synth_PA_iPad_ReplayAttack_img349724.png (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/fake/synth_PA_iPad_ReplayAttack_img314478.png (deflated 1%)
#   adding: kaggle/working/dataset3_split/test/fake/rose_fake_Mf_NT_HS_wg_E_13_76_frame_0008.jpg (deflated 1%)
#   adding: kaggle/working/dataset3_split/test/fake/synth_PA_Samsung_ReplayAttack_img112473.png (deflated 1%)
#   adding: kaggle/working/dataset3_split/test/fake/synth_PA_iPad_ReplayAttack_img430460.png (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/fake/synth_PA_Samsung_ReplayAttack_img152199.png (deflated 1%)
#   adding: kaggle/working/dataset3_split/test/fake/synth_PA_iPad_ReplayAttack_img424081.png (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/fake/rose_fake_Mc_NT_5s_g_E_7_27_frame_0009.jpg (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/fake/rose_fake_Vl_NT_HS_wg_E_20_147_frame_0002.jpg (deflated 1%)
#   adding: kaggle/working/dataset3_split/test/fake/rose_fake_Ps_NT_IP_g_E_18_133_frame_0010.jpg (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/fake/rose_fake_Mc_NT_5s_g_E_16_52_frame_0014.jpg (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/fake/synth_PA_Samsung_ReplayAttack_img371687.png (deflated 1%)
#   adding: kaggle/working/dataset3_split/test/fake/synth_PA_Samsung_ReplayAttack_img148130.png (deflated 1%)
#   adding: kaggle/working/dataset3_split/test/fake/rose_fake_Ps_NT_HS_g_E_14_125_frame_0002.jpg (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/fake/synth_PA_iPad_ReplayAttack_img355930.png (deflated 1%)
#   adding: kaggle/working/dataset3_split/test/fake/synth_PA_iPad_ReplayAttack_img074896.png (deflated 1%)
#   adding: kaggle/working/dataset3_split/test/fake/synth_PA_Samsung_ReplayAttack_img389718.png (deflated 1%)
#   adding: kaggle/working/dataset3_split/test/fake/synth_PA_Samsung_ReplayAttack_img368788.png (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/fake/synth_PA_iPad_ReplayAttack_img166863.png (deflated 1%)
#   adding: kaggle/working/dataset3_split/test/fake/rose_fake_Ps_NT_IP_g_E_21_134_frame_0020.jpg (deflated 1%)
#   adding: kaggle/working/dataset3_split/test/fake/rose_fake_Mu_NT_HS_g_E_16_84_frame_0010.jpg (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/fake/synth_PA_iPad_ReplayAttack_img132521.png (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/fake/rose_fake_Mf_NT_HS_wg_E_20_74_frame_0015.jpg (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/fake/synth_PA_iPad_ReplayAttack_img141607.png (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/fake/synth_PA_iPad_ReplayAttack_img068361.png (deflated 1%)
#   adding: kaggle/working/dataset3_split/test/fake/synth_PA_Samsung_ReplayAttack_img107041.png (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/fake/rose_fake_Mc_T_HS_g_E_16_64_frame_0022.jpg (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/fake/synth_PA_Webcam_ReplayAttack_img062092.png (deflated 1%)
#   adding: kaggle/working/dataset3_split/test/fake/rose_fake_Vl_NT_ZTE_wg_E_12_159_frame_0009.jpg (deflated 1%)
#   adding: kaggle/working/dataset3_split/test/fake/synth_PA_Samsung_ReplayAttack_img391894.png (deflated 2%)
#   adding: kaggle/working/dataset3_split/test/fake/synth_PA_iPad_ReplayAttack_img064577.png (deflated 1%)
#   adding: kaggle/working/dataset3_split/test/fake/synth_PA_Samsung_ReplayAttack_img385622.png (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/fake/synth_PA_iPad_ReplayAttack_img554415.png (deflated 1%)
#   adding: kaggle/working/dataset3_split/test/fake/rose_fake_Pq_NT_ZTE_wg_E_23_94_frame_0006.jpg (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/fake/synth_PA_Samsung_ReplayAttack_img431424.png (deflated 1%)
#   adding: kaggle/working/dataset3_split/test/fake/rose_fake_Vm_NT_ZTE_wg_E_15_152_frame_0012.jpg (deflated 1%)
#   adding: kaggle/working/dataset3_split/test/fake/rose_fake_Mc_NT_ZTE_g_E_11_59_frame_0002.jpg (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/fake/synth_PA_Samsung_ReplayAttack_img276134.png (deflated 1%)
#   adding: kaggle/working/dataset3_split/test/fake/synth_PA_Samsung_ReplayAttack_img229317.png (deflated 1%)
#   adding: kaggle/working/dataset3_split/test/fake/synth_PA_Samsung_ReplayAttack_img052960.png (deflated 1%)
#   adding: kaggle/working/dataset3_split/test/fake/synth_PA_Samsung_ReplayAttack_img168055.png (deflated 1%)
#   adding: kaggle/working/dataset3_split/test/fake/rose_fake_Mc_NT_5s_g_E_16_52_frame_0006.jpg (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/fake/synth_PA_Samsung_ReplayAttack_img450119.png (deflated 1%)
#   adding: kaggle/working/dataset3_split/test/fake/rose_fake_Vl_NT_HS_wg_E_10_120_frame_0008.jpg (deflated 2%)
#   adding: kaggle/working/dataset3_split/test/fake/rose_fake_Vl_NT_ZTE_wg_E_23_134_frame_0011.jpg (deflated 1%)
#   adding: kaggle/working/dataset3_split/test/fake/rose_fake_Pq_NT_5s_wg_E_23_76_frame_0011.jpg (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/fake/synth_PA_Samsung_ReplayAttack_img418415.png (deflated 1%)
#   adding: kaggle/working/dataset3_split/test/fake/synth_PA_iPad_ReplayAttack_img475833.png (deflated 1%)
#   adding: kaggle/working/dataset3_split/test/fake/rose_fake_Ps_NT_IP_g_E_2_133_frame_0023.jpg (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/fake/synth_PA_Webcam_ReplayAttack_img432456.png (deflated 1%)
#   adding: kaggle/working/dataset3_split/test/fake/synth_PA_iPad_ReplayAttack_img319129.png (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/fake/synth_PA_Samsung_ReplayAttack_img289915.png (deflated 1%)
#   adding: kaggle/working/dataset3_split/test/fake/synth_PA_Samsung_ReplayAttack_img032116.png (deflated 1%)
#   adding: kaggle/working/dataset3_split/test/fake/synth_PA_iPad_ReplayAttack_img468104.png (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/fake/synth_PA_Samsung_ReplayAttack_img005119.png (deflated 1%)
#   adding: kaggle/working/dataset3_split/test/fake/rose_fake_Vl_NT_HS_wg_E_15_121_frame_0009.jpg (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/fake/rose_fake_Mu_T_5s_g_E_21_92_frame_0004.jpg (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/fake/synth_PA_iPad_ReplayAttack_img379992.png (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/fake/synth_PA_Samsung_ReplayAttack_img113799.png (deflated 1%)
#   adding: kaggle/working/dataset3_split/test/fake/synth_PA_iPad_ReplayAttack_img476958.png (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/fake/synth_PA_iPad_ReplayAttack_img521882.png (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/fake/synth_PA_PrintAttack_img012351.png (deflated 2%)
#   adding: kaggle/working/dataset3_split/test/fake/synth_PA_Webcam_ReplayAttack_img109898.png (deflated 2%)
#   adding: kaggle/working/dataset3_split/test/fake/synth_PA_Webcam_ReplayAttack_img320555.png (deflated 1%)
#   adding: kaggle/working/dataset3_split/test/fake/synth_PA_iPad_ReplayAttack_img271653.png (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/fake/synth_PA_Samsung_ReplayAttack_img300571.png (deflated 1%)
#   adding: kaggle/working/dataset3_split/test/fake/synth_PA_iPad_ReplayAttack_img140373.png (deflated 1%)
#   adding: kaggle/working/dataset3_split/test/fake/synth_PA_iPad_ReplayAttack_img529413.png (deflated 1%)
#   adding: kaggle/working/dataset3_split/test/fake/rose_fake_Ps_NT_HS_wg_E_20_126_frame_0018.jpg (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/fake/rose_fake_Mc_NT_5s_g_E_3_52_frame_0004.jpg (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/fake/synth_PA_iPad_ReplayAttack_img211074.png (deflated 1%)
#   adding: kaggle/working/dataset3_split/test/fake/synth_PA_iPad_ReplayAttack_img505053.png (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/fake/rose_fake_Vm_NT_ZTE_g_E_6_177_frame_0008.jpg (deflated 1%)
#   adding: kaggle/working/dataset3_split/test/fake/synth_PA_Webcam_ReplayAttack_img099793.png (deflated 2%)
#   adding: kaggle/working/dataset3_split/test/fake/synth_PA_Webcam_ReplayAttack_img543352.png (deflated 1%)
#   adding: kaggle/working/dataset3_split/test/fake/rose_fake_Mc_T_HS_g_E_3_64_frame_0019.jpg (deflated 1%)
#   adding: kaggle/working/dataset3_split/test/fake/synth_PA_iPad_ReplayAttack_img335536.png (deflated 1%)
#   adding: kaggle/working/dataset3_split/test/fake/rose_fake_Mu_T_ZTE_g_E_21_100_frame_0007.jpg (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/fake/rose_fake_Mu_NT_ZTE_g_E_17_89_frame_0005.jpg (deflated 1%)
#   adding: kaggle/working/dataset3_split/test/fake/synth_PA_Samsung_ReplayAttack_img140554.png (deflated 1%)
#   adding: kaggle/working/dataset3_split/test/fake/synth_PA_Samsung_ReplayAttack_img209167.png (deflated 1%)
#   adding: kaggle/working/dataset3_split/test/fake/rose_fake_Vm_NT_IP_wg_E_23_149_frame_0018.jpg (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/fake/rose_fake_Pq_NT_HW_wg_E_13_113_frame_0003.jpg (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/fake/rose_fake_Mf_NT_5s_g_E_13_73_frame_0019.jpg (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/fake/rose_fake_Vm_NT_5s_wg_E_23_136_frame_0012.jpg (deflated 2%)
#   adding: kaggle/working/dataset3_split/test/fake/synth_PA_Samsung_ReplayAttack_img261260.png (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/fake/rose_fake_Mf_NT_5s_g_E_3_71_frame_0021.jpg (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/fake/synth_PA_Samsung_ReplayAttack_img513304.png (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/fake/synth_PA_Samsung_ReplayAttack_img036129.png (deflated 1%)
#   adding: kaggle/working/dataset3_split/test/fake/synth_PA_PrintAttack_img006527.png (deflated 1%)
#   adding: kaggle/working/dataset3_split/test/fake/synth_PA_Webcam_ReplayAttack_img073514.png (deflated 1%)
#   adding: kaggle/working/dataset3_split/test/fake/synth_PA_PrintAttack_img074937.png (deflated 2%)
#   adding: kaggle/working/dataset3_split/test/fake/synth_PA_iPad_ReplayAttack_img519777.png (deflated 1%)
#   adding: kaggle/working/dataset3_split/test/fake/rose_fake_Ps_NT_IP_g_E_18_134_frame_0013.jpg (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/fake/synth_PA_iPad_ReplayAttack_img335087.png (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/fake/synth_PA_iPad_ReplayAttack_img400531.png (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/fake/synth_PA_Samsung_ReplayAttack_img080801.png (deflated 1%)
#   adding: kaggle/working/dataset3_split/test/fake/rose_fake_Vm_NT_HS_wg_E_16_167_frame_0011.jpg (deflated 1%)
#   adding: kaggle/working/dataset3_split/test/fake/rose_fake_Vl_NT_HS_wg_E_6_147_frame_0002.jpg (deflated 1%)
#   adding: kaggle/working/dataset3_split/test/fake/rose_fake_Vm_NT_HS_wg_E_23_140_frame_0022.jpg (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/fake/synth_PA_iPad_ReplayAttack_img087194.png (deflated 1%)
#   adding: kaggle/working/dataset3_split/test/fake/rose_fake_Vm_NT_HS_g_E_18_166_frame_0013.jpg (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/fake/synth_PA_PrintAttack_img072329.png (deflated 2%)
#   adding: kaggle/working/dataset3_split/test/fake/synth_PA_Samsung_ReplayAttack_img384603.png (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/fake/synth_PA_Samsung_ReplayAttack_img292628.png (deflated 1%)
#   adding: kaggle/working/dataset3_split/test/fake/synth_PA_iPad_ReplayAttack_img380684.png (deflated 1%)
#   adding: kaggle/working/dataset3_split/test/fake/synth_PA_iPad_ReplayAttack_img355981.png (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/fake/synth_PA_Samsung_ReplayAttack_img553606.png (deflated 1%)
#   adding: kaggle/working/dataset3_split/test/fake/synth_PA_iPad_ReplayAttack_img427232.png (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/fake/synth_PA_PrintAttack_img074876.png (deflated 3%)
#   adding: kaggle/working/dataset3_split/test/fake/rose_fake_Vm_NT_5s_wg_E_7_136_frame_0011.jpg (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/fake/synth_PA_iPad_ReplayAttack_img489914.png (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/fake/synth_PA_Samsung_ReplayAttack_img152906.png (deflated 1%)
#   adding: kaggle/working/dataset3_split/test/fake/rose_fake_Pq_NT_5s_g_E_13_103_frame_0008.jpg (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/fake/synth_PA_Samsung_ReplayAttack_img318678.png (deflated 1%)
#   adding: kaggle/working/dataset3_split/test/fake/rose_fake_Mu_NT_HW_g_E_6_85_frame_0006.jpg (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/fake/rose_fake_Pq_NT_IP_wg_E_23_91_frame_0016.jpg (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/fake/rose_fake_Ps_NT_5s_wg_E_20_122_frame_0007.jpg (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/fake/synth_PA_Samsung_ReplayAttack_img143004.png (deflated 1%)
#   adding: kaggle/working/dataset3_split/test/fake/synth_PA_iPad_ReplayAttack_img468207.png (deflated 1%)
#   adding: kaggle/working/dataset3_split/test/fake/synth_PA_iPad_ReplayAttack_img419319.png (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/fake/synth_PA_iPad_ReplayAttack_img116278.png (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/fake/synth_PA_Samsung_ReplayAttack_img515913.png (deflated 1%)
#   adding: kaggle/working/dataset3_split/test/fake/rose_fake_Vm_NT_ZTE_g_E_13_179_frame_0019.jpg (deflated 1%)
#   adding: kaggle/working/dataset3_split/test/fake/rose_fake_Mf_NT_IP_wg_E_17_78_frame_0006.jpg (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/fake/synth_PA_Samsung_ReplayAttack_img076573.png (deflated 1%)
#   adding: kaggle/working/dataset3_split/test/fake/rose_fake_Pq_NT_ZTE_wg_E_23_94_frame_0007.jpg (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/fake/synth_PA_Samsung_ReplayAttack_img050496.png (deflated 1%)
#   adding: kaggle/working/dataset3_split/test/fake/synth_PA_Webcam_ReplayAttack_img074394.png (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/fake/rose_fake_Mu_T_HW_g_E_16_96_frame_0005.jpg (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/fake/rose_fake_Mf_NT_5s_g_E_12_70_frame_0018.jpg (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/fake/rose_fake_Pq_NT_HS_wg_E_3_107_frame_0014.jpg (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/fake/rose_fake_Vm_NT_IP_g_E_2_173_frame_0001.jpg (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/fake/rose_fake_Mc_T_ZTE_g_E_20_70_frame_0001.jpg (deflated 1%)
#   adding: kaggle/working/dataset3_split/test/fake/rose_fake_Vl_NT_IP_wg_E_10_128_frame_0018.jpg (deflated 1%)
#   adding: kaggle/working/dataset3_split/test/fake/synth_PA_iPad_ReplayAttack_img315607.png (deflated 1%)
#   adding: kaggle/working/dataset3_split/test/fake/synth_PA_Webcam_ReplayAttack_img187520.png (deflated 1%)
#   adding: kaggle/working/dataset3_split/test/fake/synth_PA_Webcam_ReplayAttack_img381189.png (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/fake/synth_PA_iPad_ReplayAttack_img017725.png (deflated 1%)
#   adding: kaggle/working/dataset3_split/test/fake/rose_fake_Vl_NT_5s_wg_E_2_143_frame_0003.jpg (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/fake/synth_PA_Samsung_ReplayAttack_img319863.png (deflated 1%)
#   adding: kaggle/working/dataset3_split/test/fake/synth_PA_Webcam_ReplayAttack_img279838.png (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/fake/synth_PA_Samsung_ReplayAttack_img498432.png (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/fake/synth_PA_iPad_ReplayAttack_img494261.png (deflated 1%)
#   adding: kaggle/working/dataset3_split/test/fake/synth_PA_Samsung_ReplayAttack_img496387.png (deflated 1%)
#   adding: kaggle/working/dataset3_split/test/fake/synth_PA_Webcam_ReplayAttack_img274228.png (deflated 1%)
#   adding: kaggle/working/dataset3_split/test/fake/synth_PA_Samsung_ReplayAttack_img130533.png (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/fake/synth_PA_iPad_ReplayAttack_img234121.png (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/fake/rose_fake_Mu_T_IP_g_E_21_98_frame_0013.jpg (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/fake/synth_PA_Samsung_ReplayAttack_img240479.png (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/fake/synth_PA_Samsung_ReplayAttack_img502523.png (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/fake/rose_fake_Ps_NT_HS_wg_E_21_127_frame_0020.jpg (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/fake/synth_PA_Samsung_ReplayAttack_img157965.png (deflated 2%)
#   adding: kaggle/working/dataset3_split/test/fake/rose_fake_Ps_NT_HS_wg_E_13_130_frame_0000.jpg (deflated 1%)
#   adding: kaggle/working/dataset3_split/test/fake/synth_PA_Samsung_ReplayAttack_img320633.png (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/fake/rose_fake_Vm_NT_IP_wg_E_14_175_frame_0011.jpg (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/fake/rose_fake_Mf_NT_HS_wg_E_15_48_frame_0001.jpg (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/fake/synth_PA_Samsung_ReplayAttack_img528592.png (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/fake/synth_PA_iPad_ReplayAttack_img092667.png (deflated 1%)
#   adding: kaggle/working/dataset3_split/test/fake/synth_PA_Samsung_ReplayAttack_img375301.png (deflated 1%)
#   adding: kaggle/working/dataset3_split/test/fake/rose_fake_Pq_NT_HW_wg_E_17_111_frame_0002.jpg (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/fake/synth_PA_Samsung_ReplayAttack_img343189.png (deflated 1%)
#   adding: kaggle/working/dataset3_split/test/fake/synth_PA_iPad_ReplayAttack_img287397.png (deflated 1%)
#   adding: kaggle/working/dataset3_split/test/fake/rose_fake_Mc_T_IP_g_E_18_67_frame_0000.jpg (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/fake/synth_PA_Webcam_ReplayAttack_img488291.png (deflated 1%)
#   adding: kaggle/working/dataset3_split/test/fake/synth_PA_Samsung_ReplayAttack_img184130.png (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/fake/synth_PA_Samsung_ReplayAttack_img201437.png (deflated 1%)
#   adding: kaggle/working/dataset3_split/test/fake/synth_PA_Samsung_ReplayAttack_img177085.png (deflated 1%)
#   adding: kaggle/working/dataset3_split/test/fake/rose_fake_Ps_NT_IP_g_E_12_133_frame_0020.jpg (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/fake/synth_PA_Samsung_ReplayAttack_img117920.png (deflated 1%)
#   adding: kaggle/working/dataset3_split/test/fake/synth_PA_iPad_ReplayAttack_img300870.png (deflated 2%)
#   adding: kaggle/working/dataset3_split/test/fake/synth_PA_Samsung_ReplayAttack_img449947.png (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/fake/rose_fake_Vl_NT_HS_wg_E_16_147_frame_0010.jpg (deflated 1%)
#   adding: kaggle/working/dataset3_split/test/fake/synth_PA_Samsung_ReplayAttack_img008836.png (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/fake/rose_fake_Vl_NT_HW_wg_E_13_154_frame_0000.jpg (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/fake/synth_PA_Samsung_ReplayAttack_img523709.png (deflated 1%)
#   adding: kaggle/working/dataset3_split/test/fake/synth_PA_Samsung_ReplayAttack_img126024.png (deflated 1%)
#   adding: kaggle/working/dataset3_split/test/fake/synth_PA_Samsung_ReplayAttack_img130572.png (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/fake/rose_fake_Ps_NT_ZTE_g_E_12_137_frame_0009.jpg (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/fake/rose_fake_Ps_NT_HS_wg_E_16_128_frame_0013.jpg (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/fake/synth_PA_Webcam_ReplayAttack_img114729.png (deflated 1%)
#   adding: kaggle/working/dataset3_split/test/fake/synth_PA_Webcam_ReplayAttack_img029687.png (deflated 1%)
#   adding: kaggle/working/dataset3_split/test/fake/rose_fake_Vl_NT_HS_wg_E_7_120_frame_0016.jpg (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/fake/synth_PA_Samsung_ReplayAttack_img476636.png (deflated 1%)
#   adding: kaggle/working/dataset3_split/test/fake/synth_PA_Webcam_ReplayAttack_img059512.png (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/fake/synth_PA_Samsung_ReplayAttack_img174845.png (deflated 1%)
#   adding: kaggle/working/dataset3_split/test/fake/synth_PA_iPad_ReplayAttack_img449187.png (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/fake/rose_fake_Mf_NT_IP_g_E_2_77_frame_0005.jpg (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/fake/synth_PA_Samsung_ReplayAttack_img149253.png (deflated 1%)
#   adding: kaggle/working/dataset3_split/test/fake/rose_fake_Pq_NT_5s_wg_E_12_104_frame_0023.jpg (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/fake/rose_fake_Ps_NT_HS_wg_E_15_100_frame_0001.jpg (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/fake/synth_PA_iPad_ReplayAttack_img317682.png (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/fake/rose_fake_Mf_NT_ZTE_g_E_3_79_frame_0002.jpg (deflated 1%)
#   adding: kaggle/working/dataset3_split/test/fake/synth_PA_Samsung_ReplayAttack_img352182.png (deflated 1%)
#   adding: kaggle/working/dataset3_split/test/fake/synth_PA_iPad_ReplayAttack_img462267.png (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/fake/synth_PA_Samsung_ReplayAttack_img039933.png (deflated 1%)
#   adding: kaggle/working/dataset3_split/test/fake/rose_fake_Pq_NT_IP_wg_E_10_87_frame_0004.jpg (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/fake/synth_PA_iPad_ReplayAttack_img409840.png (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/fake/synth_PA_iPad_ReplayAttack_img249933.png (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/fake/rose_fake_Mu_T_HS_g_E_16_93_frame_0023.jpg (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/fake/rose_fake_Pq_NT_5s_wg_E_7_78_frame_0010.jpg (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/fake/synth_PA_Samsung_ReplayAttack_img089326.png (deflated 2%)
#   adding: kaggle/working/dataset3_split/test/fake/rose_fake_Mc_NT_HW_g_E_4_55_frame_0013.jpg (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/fake/synth_PA_PrintAttack_img040770.png (deflated 2%)
#   adding: kaggle/working/dataset3_split/test/fake/synth_PA_Webcam_ReplayAttack_img548825.png (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/fake/synth_PA_Webcam_ReplayAttack_img224025.png (deflated 2%)
#   adding: kaggle/working/dataset3_split/test/fake/rose_fake_Mf_NT_IP_g_E_13_79_frame_0004.jpg (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/fake/synth_PA_Samsung_ReplayAttack_img076829.png (deflated 2%)
#   adding: kaggle/working/dataset3_split/test/fake/synth_PA_iPad_ReplayAttack_img337875.png (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/fake/rose_fake_Pq_NT_HS_g_E_6_106_frame_0000.jpg (deflated 1%)
#   adding: kaggle/working/dataset3_split/test/fake/synth_PA_Samsung_ReplayAttack_img430693.png (deflated 1%)
#   adding: kaggle/working/dataset3_split/test/fake/synth_PA_iPad_ReplayAttack_img439899.png (deflated 1%)
#   adding: kaggle/working/dataset3_split/test/fake/synth_PA_Webcam_ReplayAttack_img516133.png (deflated 1%)
#   adding: kaggle/working/dataset3_split/test/fake/rose_fake_Pq_NT_5s_wg_E_4_105_frame_0018.jpg (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/fake/synth_PA_iPad_ReplayAttack_img111024.png (deflated 1%)
#   adding: kaggle/working/dataset3_split/test/fake/synth_PA_Webcam_ReplayAttack_img442213.png (deflated 1%)
#   adding: kaggle/working/dataset3_split/test/fake/synth_PA_iPad_ReplayAttack_img317430.png (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/fake/rose_fake_Mf_NT_IP_wg_E_20_78_frame_0003.jpg (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/fake/synth_PA_iPad_ReplayAttack_img507996.png (deflated 2%)
#   adding: kaggle/working/dataset3_split/test/fake/synth_PA_iPad_ReplayAttack_img269058.png (deflated 1%)
#   adding: kaggle/working/dataset3_split/test/fake/rose_fake_Vm_NT_IP_g_E_14_173_frame_0014.jpg (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/fake/synth_PA_iPad_ReplayAttack_img328045.png (deflated 1%)
#   adding: kaggle/working/dataset3_split/test/fake/synth_PA_iPad_ReplayAttack_img519045.png (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/fake/rose_fake_Mc_T_IP_g_E_10_42_frame_0022.jpg (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/fake/rose_fake_Mf_NT_HS_g_E_9_73_frame_0008.jpg (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/fake/rose_fake_Pq_NT_HS_wg_E_15_81_frame_0011.jpg (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/fake/synth_PA_Webcam_ReplayAttack_img218635.png (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/fake/synth_PA_Samsung_ReplayAttack_img447746.png (deflated 1%)
#   adding: kaggle/working/dataset3_split/test/fake/synth_PA_Webcam_ReplayAttack_img171837.png (deflated 1%)
# ...
#   adding: kaggle/working/dataset3_split/test/real/synth_BonaFide_img057933.png (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/real/synth_BonaFide_img187169.png (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/real/rose_real_G_NT_ZTE_wg_E_4_46_frame_0021.jpg (deflated 1%)
#   adding: kaggle/working/dataset3_split/test/real/synth_BonaFide_img346609.png (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/real/synth_BonaFide_img039175.png (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/real/synth_BonaFide_img420801.png (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/real/synth_BonaFide_img162241.png (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/real/synth_BonaFide_img464947.png (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/real/synth_BonaFide_img455347.png (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/real/rose_real_G_NT_HS_wg_E_23_8_frame_0016.jpg (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/real/synth_BonaFide_img303571.png (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/real/synth_BonaFide_img545280.png (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/real/synth_BonaFide_img532902.png (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/real/rose_real_G_NT_HW_wg_E_23_13_frame_0008.jpg (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/real/synth_BonaFide_img216332.png (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/real/synth_BonaFide_img230073.png (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/real/synth_BonaFide_img160059.png (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/real/synth_BonaFide_img168708.png (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/real/rose_real_G_NT_HW_g_E_3_23_frame_0001.jpg (deflated 1%)
#   adding: kaggle/working/dataset3_split/test/real/synth_BonaFide_img089071.png (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/real/rose_real_G_NT_HW_g_E_16_23_frame_0005.jpg (deflated 1%)
#   adding: kaggle/working/dataset3_split/test/real/synth_BonaFide_img184533.png (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/real/rose_real_G_NT_HW_wg_E_18_27_frame_0001.jpg (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/real/synth_BonaFide_img159859.png (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/real/synth_BonaFide_img152661.png (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/real/synth_BonaFide_img436884.png (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/real/synth_BonaFide_img335096.png (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/real/rose_real_G_NT_ZTE_g_E_17_44_frame_0002.jpg (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/real/rose_real_G_NT_ZTE_g_E_14_41_frame_0003.jpg (deflated 1%)
#   adding: kaggle/working/dataset3_split/test/real/rose_real_G_NT_ZTE_g_E_13_42_frame_0010.jpg (deflated 1%)
#   adding: kaggle/working/dataset3_split/test/real/rose_real_G_NT_5s_g_E_14_4_frame_0020.jpg (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/real/rose_real_G_NT_ZTE_g_E_11_42_frame_0009.jpg (deflated 1%)
#   adding: kaggle/working/dataset3_split/test/real/rose_real_G_NT_HW_g_E_11_21_frame_0009.jpg (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/real/rose_real_G_NT_IP_g_E_9_33_frame_0023.jpg (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/real/synth_BonaFide_img445992.png (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/real/rose_real_G_NT_IP_g_E_11_32_frame_0008.jpg (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/real/synth_BonaFide_img167760.png (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/real/rose_real_G_NT_5s_wg_E_15_5_frame_0017.jpg (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/real/rose_real_G_NT_HS_wg_E_23_8_frame_0029.jpg (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/real/synth_BonaFide_img157287.png (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/real/rose_real_G_NT_ZTE_g_E_6_45_frame_0011.jpg (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/real/rose_real_G_NT_HS_g_E_17_15_frame_0015.jpg (deflated 1%)
#   adding: kaggle/working/dataset3_split/test/real/rose_real_G_NT_HW_g_E_2_21_frame_0005.jpg (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/real/synth_BonaFide_img513931.png (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/real/synth_BonaFide_img550957.png (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/real/synth_BonaFide_img014583.png (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/real/synth_BonaFide_img355407.png (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/real/synth_BonaFide_img015207.png (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/real/synth_BonaFide_img046368.png (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/real/rose_real_G_NT_HS_wg_E_2_20_frame_0012.jpg (deflated 1%)
#   adding: kaggle/working/dataset3_split/test/real/synth_BonaFide_img096009.png (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/real/rose_real_G_NT_HS_g_E_21_15_frame_0021.jpg (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/real/rose_real_G_NT_IP_wg_E_13_37_frame_0018.jpg (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/real/synth_BonaFide_img221551.png (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/real/synth_BonaFide_img120203.png (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/real/rose_real_G_NT_5s_g_E_12_3_frame_0011.jpg (deflated 1%)
#   adding: kaggle/working/dataset3_split/test/real/rose_real_G_NT_ZTE_g_E_3_43_frame_0000.jpg (deflated 2%)
#   adding: kaggle/working/dataset3_split/test/real/rose_real_G_NT_HS_wg_E_14_19_frame_0020.jpg (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/real/rose_real_G_NT_IP_wg_E_6_39_frame_0012.jpg (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/real/rose_real_G_NT_IP_wg_E_2_36_frame_0021.jpg (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/real/synth_BonaFide_img171532.png (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/real/synth_BonaFide_img207478.png (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/real/rose_real_G_NT_HW_g_E_6_25_frame_0014.jpg (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/real/rose_real_G_NT_HW_g_E_12_23_frame_0007.jpg (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/real/synth_BonaFide_img355975.png (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/real/synth_BonaFide_img367243.png (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/real/synth_BonaFide_img021918.png (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/real/rose_real_G_NT_5s_wg_E_2_6_frame_0006.jpg (deflated 1%)
#   adding: kaggle/working/dataset3_split/test/real/synth_BonaFide_img337106.png (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/real/synth_BonaFide_img170173.png (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/real/synth_BonaFide_img011968.png (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/real/synth_BonaFide_img001620.png (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/real/synth_BonaFide_img524942.png (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/real/synth_BonaFide_img505554.png (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/real/rose_real_G_NT_IP_g_E_16_32_frame_0012.jpg (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/real/synth_BonaFide_img175429.png (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/real/rose_real_G_NT_IP_wg_E_4_38_frame_0008.jpg (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/real/rose_real_G_NT_5s_g_E_12_2_frame_0010.jpg (deflated 1%)
#   adding: kaggle/working/dataset3_split/test/real/synth_BonaFide_img183612.png (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/real/synth_BonaFide_img124040.png (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/real/synth_BonaFide_img150094.png (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/real/synth_BonaFide_img240178.png (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/real/rose_real_G_NT_HS_wg_E_18_20_frame_0017.jpg (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/real/synth_BonaFide_img168593.png (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/real/synth_BonaFide_img528177.png (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/real/rose_real_G_NT_5s_wg_E_4_9_frame_0013.jpg (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/real/synth_BonaFide_img154170.png (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/real/synth_BonaFide_img213855.png (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/real/synth_BonaFide_img256135.png (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/real/rose_real_G_NT_HW_g_E_6_22_frame_0012.jpg (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/real/synth_BonaFide_img277112.png (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/real/synth_BonaFide_img206678.png (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/real/synth_BonaFide_img531262.png (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/real/rose_real_G_NT_HW_wg_E_13_26_frame_0004.jpg (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/real/synth_BonaFide_img465459.png (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/real/synth_BonaFide_img327978.png (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/real/rose_real_G_NT_HS_wg_E_15_9_frame_0018.jpg (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/real/synth_BonaFide_img353046.png (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/real/rose_real_G_NT_ZTE_g_E_16_45_frame_0004.jpg (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/real/synth_BonaFide_img450203.png (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/real/synth_BonaFide_img224818.png (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/real/rose_real_G_NT_5s_wg_E_13_9_frame_0016.jpg (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/real/synth_BonaFide_img024592.png (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/real/rose_real_G_NT_HW_g_E_14_21_frame_0009.jpg (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/real/synth_BonaFide_img543540.png (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/real/synth_BonaFide_img216999.png (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/real/rose_real_G_NT_HS_g_E_20_11_frame_0001.jpg (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/real/synth_BonaFide_img499303.png (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/real/synth_BonaFide_img379449.png (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/real/synth_BonaFide_img476451.png (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/real/synth_BonaFide_img485687.png (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/real/rose_real_G_NT_HW_wg_E_15_13_frame_0007.jpg (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/real/rose_real_G_NT_HW_wg_E_3_26_frame_0007.jpg (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/real/rose_real_G_NT_5s_wg_E_3_7_frame_0013.jpg (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/real/synth_BonaFide_img498286.png (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/real/rose_real_G_NT_IP_wg_E_15_19_frame_0026.jpg (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/real/rose_real_G_NT_ZTE_wg_E_3_49_frame_0009.jpg (deflated 1%)
#   adding: kaggle/working/dataset3_split/test/real/rose_real_G_NT_5s_wg_E_12_7_frame_0019.jpg (deflated 1%)
#   adding: kaggle/working/dataset3_split/test/real/synth_BonaFide_img307340.png (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/real/synth_BonaFide_img382856.png (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/real/rose_real_G_NT_HW_wg_E_2_26_frame_0015.jpg (deflated 1%)
#   adding: kaggle/working/dataset3_split/test/real/synth_BonaFide_img345994.png (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/real/rose_real_G_NT_ZTE_g_E_4_41_frame_0017.jpg (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/real/rose_real_G_NT_HW_wg_E_16_30_frame_0016.jpg (deflated 1%)
#   adding: kaggle/working/dataset3_split/test/real/synth_BonaFide_img422201.png (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/real/synth_BonaFide_img495847.png (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/real/synth_BonaFide_img385346.png (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/real/synth_BonaFide_img292952.png (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/real/synth_BonaFide_img423214.png (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/real/synth_BonaFide_img081869.png (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/real/rose_real_G_NT_HW_wg_E_18_26_frame_0003.jpg (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/real/synth_BonaFide_img200376.png (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/real/rose_real_G_NT_IP_wg_E_21_40_frame_0016.jpg (deflated 1%)
#   adding: kaggle/working/dataset3_split/test/real/synth_BonaFide_img466776.png (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/real/synth_BonaFide_img354446.png (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/real/synth_BonaFide_img271683.png (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/real/synth_BonaFide_img048766.png (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/real/rose_real_G_NT_HS_g_E_2_11_frame_0031.jpg (deflated 1%)
#   adding: kaggle/working/dataset3_split/test/real/synth_BonaFide_img359924.png (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/real/rose_real_G_NT_IP_wg_E_12_39_frame_0013.jpg (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/real/rose_real_G_NT_HS_wg_E_13_19_frame_0023.jpg (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/real/synth_BonaFide_img488313.png (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/real/synth_BonaFide_img248060.png (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/real/synth_BonaFide_img033527.png (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/real/rose_real_G_NT_HS_wg_E_18_17_frame_0013.jpg (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/real/rose_real_G_NT_HS_wg_E_2_16_frame_0016.jpg (deflated 1%)
#   adding: kaggle/working/dataset3_split/test/real/rose_real_G_NT_HS_wg_E_14_18_frame_0015.jpg (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/real/rose_real_G_NT_5s_wg_E_2_7_frame_0014.jpg (deflated 1%)
#   adding: kaggle/working/dataset3_split/test/real/synth_BonaFide_img450924.png (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/real/synth_BonaFide_img389937.png (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/real/rose_real_G_NT_HW_g_E_18_21_frame_0006.jpg (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/real/synth_BonaFide_img185878.png (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/real/rose_real_G_NT_HS_wg_E_15_6_frame_0002.jpg (deflated 1%)
#   adding: kaggle/working/dataset3_split/test/real/synth_BonaFide_img279707.png (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/real/synth_BonaFide_img409953.png (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/real/rose_real_G_NT_ZTE_g_E_11_41_frame_0006.jpg (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/real/synth_BonaFide_img316108.png (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/real/rose_real_G_NT_HS_wg_E_6_17_frame_0016.jpg (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/real/synth_BonaFide_img237354.png (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/real/synth_BonaFide_img117900.png (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/real/synth_BonaFide_img131142.png (deflated 0%)
#   adding: kaggle/working/dataset3_split/test/real/synth_BonaFide_img554596.png (deflated 0%)

# %%
# 8. Final evaluation
from tensorflow.keras.metrics import AUC
from tensorflow.keras.models import load_model
from tensorflow.keras.metrics import AUC
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt
import numpy as np

# Load and compile model
model = load_model('/kaggle/working/EB0_all_v2.keras', compile=False)
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy', AUC()])

# Load test dataset
test_ds = build_ds('/kaggle/working/dataset3_split/test')

# Evaluate
loss, acc, auc = model.evaluate(test_ds, verbose=2)
print(f"Test → loss: {loss:.4f}, acc: {acc:.4f}, auc: {auc:.4f}")

# Generate confusion matrix
y_true = np.concatenate([y.numpy() for _, y in test_ds], axis=0)
preds = model.predict(test_ds)
y_pred = np.argmax(preds, axis=1)
y_true = np.argmax(y_true, axis=1)

cm = confusion_matrix(y_true, y_pred)
disp = ConfusionMatrixDisplay(cm, display_labels=CLASS_NAMES)
disp.plot(cmap=plt.cm.Blues)
plt.title("Combined Test Confusion Matrix")
plt.show()
# Out:
# Found 11217 files belonging to 2 classes.
# 88/88 - 26s - 300ms/step - accuracy: 0.9994 - auc_1: 1.0000 - loss: 0.0106
# Test → loss: 0.0106, acc: 0.9994, auc: 1.0000
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 27s 228ms/step

# %%
import tensorflow as tf
import numpy as np
from tensorflow.keras.models import load_model
from tensorflow.keras.utils import load_img, img_to_array

# Define the path to the image you want to predict
img_path = '/kaggle/input/frames-replay-attack/real/client002_session01_webcam_authenticate_controlled_1/client002_session01_webcam_authenticate_controlled_1_frame_000.jpg'  # Update with your image path

# Load and preprocess the image
img = load_img(img_path, target_size=(224, 224))  # Adjust target_size if your model expects a different input size
img_array = img_to_array(img)
img_array = np.expand_dims(img_array, axis=0)  # Create batch axis
img_array = img_array / 255.0  # Normalize pixel values to [0, 1] if required by your model

# Load the trained model
model = load_model('/kaggle/working/EB0_all_v2.keras', compile=False)

# Make prediction
predictions = model.predict(img_array)
predicted_class = np.argmax(predictions, axis=1)[0]

# Map the predicted class index to the class name
CLASS_NAMES = ['real', 'fake']  # Replace with your actual class names
print(f"Predicted class: {CLASS_NAMES[predicted_class]}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 7s 7s/step
# Predicted class: fake

# %%
# #Delete a particular contents of Output directory
# import shutil
# import os

# working_dir = '/kaggle/working/dataset3'

# # Loop through all items and remove them
# for item in os.listdir(working_dir):
#     item_path = os.path.join(working_dir, item)
#     try:
#         if os.path.isfile(item_path) or os.path.islink(item_path):
#             os.remove(item_path)
#         elif os.path.isdir(item_path):
#             shutil.rmtree(item_path)
#     except Exception as e:
#         print(f'Failed to delete {item_path}. Reason: {e}')

# print(f"All contents of {working_dir} have been deleted.")
